# %% [markdown]
# # Dagua Interactive Playground
#
# Use this notebook to build intuition for layout defaults. Turn the dials, watch the nodes move, and monitor the placement metrics in real time.

# %%
import dagua

# %%
dagua.launch_playground()
